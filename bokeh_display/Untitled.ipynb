# %%
import iris
import iris.quickplot as qplt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cube = iris.load_cube('/project/MJO_GCSS/MJO_monitoring/processed_MJO_data/analysis/olr/2018/10/02/qg00T000.2_5.nc')
lons = cube.coord('longitude').points
lats = cube.coord('latitude').points

# %%
cs = qplt.contour(cube)
print dir(plt.gca().coastlines())
# Out:
# ['__class__', '__delattr__', '__dict__', '__doc__', '__format__', '__getattribute__', '__getstate__', '__hash__', '__init__', '__module__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_agg_filter', '_alpha', '_animated', '_axes', '_clipon', '_clippath', '_contains', '_feature', '_geom_key_to_geometry_cache', '_geom_key_to_path_cache', '_gid', '_kwargs', '_label', '_mouseover', '_oid', '_path_effects', '_picker', '_propobservers', '_rasterized', '_remove_method', '_set_gc_clip', '_sketch', '_snap', '_stale', '_transform', '_transformSet', '_url', '_visible', 'add_callback', 'aname', 'axes', 'clipbox', 'contains', 'convert_xunits', 'convert_yunits', 'draw', 'eventson', 'figure', 'findobj', 'format_cursor_data', 'get_agg_filter', 'get_alpha', 'get_animated', 'get_axes', 'get_children', 'get_clip_box', 'get_clip_on', 'get_clip_path', 'get_contains', 'get_cursor_data', 'get_figure', 'get_gid', 'get_label
# ...

# %%
import glob

# %%
glob.glob('/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/*/*/*')
# Out:
# ['/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/02',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/05',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/08',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/21',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/24',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/27',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/11',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/19',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/14',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/17',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/01',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/09',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/04',
#  '/project/MJO_GCSS/MJO_monitoring/raw_data/mogreps/2018/02/07',
# ...
